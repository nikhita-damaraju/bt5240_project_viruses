# %%
#program to merge all csv file data into one single file
import os
import glob
import pandas as pd
import numpy as np
os.chdir("/Users/nikhitadamaraju/Desktop/Systems Biology/Project/RNA_negative_viruses")
all_filenames = glob.glob("*human.csv")

def unique(list1): 
    x = np.array(list1) 
    return (np.unique(x)) 

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

df = pd.read_csv("combined_csv.csv")
prot_list = (list(df['prot_id']))
unique_list = unique(prot_list)
df_new = pd.DataFrame()
df_new['prot_id'] = unique_list

df_new.to_csv("rna_negative.csv",index=False,header= False)

# %%
#script to look at most frequent proteins in file <combined.csv>
import pandas as pd
import csv

# %%
df = pd.read_csv("/Users/nikhitadamaraju/Desktop/Systems Biology/Project/DNA/combined_csv.csv")

# %%
df.groupby('prot_id').size().reset_index(name="counts").sort_values(['counts'],ascending =False)
# Out:
#                  prot_id  counts
# 42  9606.ENSP00000334499       5
# 79  9606.ENSP00000412788       5
# 64  9606.ENSP00000362153       5
# 72  9606.ENSP00000369581       5
# 11  9606.ENSP00000261233       5
# 55  9606.ENSP00000349428       5
# 4   9606.ENSP00000224784       4
# 58  9606.ENSP00000355645       4
# 26  9606.ENSP00000290378       4
# 80  9606.ENSP00000416706       4
# 8   9606.ENSP00000248598       4
# 74  9606.ENSP00000376943       3
# 56  9606.ENSP00000352738       3
# 19  9606.ENSP00000264657       3
# 7   9606.ENSP00000245923       3
# 1   9606.ENSP00000221566       2
# 44  9606.ENSP00000337838       2
# 43  9606.ENSP00000335153       2
# 50  9606.ENSP00000341551       2
# 51  9606.ENSP00000344106       2
# 41  9606.ENSP00000332973       2
# 54  9606.ENSP00000348578       2
# 47  9606.ENSP00000339191       2
# 65  9606.ENSP00000362287       2
# 57  9606.ENSP00000355231       2
# 63  9606.ENSP00000360266       2
# 36  9606.ENSP00000325875       2
# 66  9606.ENSP00000362300       2
# 67  9606.ENSP00000362306       2
# 70  9606.ENSP00000364310       2
# ..                   ...     ...
# 20  9606.ENSP00000265132       1
# 75  9606.ENSP00000380921       1
# 76  9606.ENSP00000384273       1
# 9   9606.ENSP00000251968       1
# 78  9606.ENSP00000396688       1
# 6   9606.ENSP00000239223       1
# 5   9606.ENSP00000225698       1
# 3   9606.ENSP00000222308       1
# 18  9606.ENSP00000263645       1
# 60  9606.ENSP00000356087       1
# 62  9606.ENSP00000359424       1
# 61  9606.ENSP00000356224       1
# 38  9606.ENSP00000329623       1
# 39  9606.ENSP00000329967       1
# 40  9606.ENSP00000332152       1
# 31  9606.ENSP00000304350       1
# 45  9606.ENSP00000338020       1
# 46  9606.ENSP00000339007       1
# 29  9606.ENSP00000301244       1
# 48  9606.ENSP00000340691       1
# 49  9606.ENSP00000341268       1
# 27  9606.ENSP00000293288       1
# 52  9606.ENSP00000345656       1
# 53  9606.ENSP00000346694       1
# 24  9606.ENSP00000279488       1
# 23  9606.ENSP00000270202       1
# 22  9606.ENSP00000269305       1
# 59  9606.ENSP00000355759       1
# 34  9606.ENSP00000313829       1
# 0   9606.ENSP00000220592       1
#
# [84 rows x 2 columns]
